# %% [markdown]
# # Clustering Named Entities with InfoLeg
# #### Mining for insights in legal texts

# %% [markdown]
# InfoLeg is a legistative database for the *Ministerio de Justicia y Derechos Humanos de la Nación* in Argentina.

# %%
import spacy
import nltk
from spacy.tokens import Doc
import re
import os
import numpy as np
import pandas as pd
from nltk import regexp_tokenize
from nltk import sent_tokenize
from collections import defaultdict
from sklearn.feature_extraction import DictVectorizer
from sklearn.cluster import KMeans
from sklearn import preprocessing

# %%
PATH = './entities_infoleg/'

# %% [markdown]
# When dealing with multi-word named entities, such as 'Ley Nº 26.442', in **regular expressions** help us to isolate such words and look for patterns of their use in the texts.
# These regex patterns were created by Lucas Agustin De Francesca, https://github.com/lucasdefrancesca/text-mining.

# %%
# regex pattern #these patterns are from Lucas Agustin De Francesca, https://github.com/lucasdefrancesca/text-mining
PATTERN = r'''(?x)
   (?:Ley\sN[ºo°]*\s\d{1,}(?:\.\d+)*)                # Leyes como entidad
   | (?:[Aa]nexo[s]?[\sIVXLCDMy,]*[IVXLCDM]+)        # anexos
   | (?:Nota[\sA-Za-z()ºo°\.]+[\d|/]+)               # Notas como entidad
   | (?:Decreto[A-Zºo°\sa-z]+[\d|/]+)                # Decretos como entidad
   | (?:[Aa]rt[ií]culo[A-Z|\sºo°]+\d+º*)             # Articulos como entidad
   | (?:[Aa]rt\.*[\s+\d+]+º*)                        # abreviacion de articulo
   | (?:Resoluci[óo]n[A-Zºo°\sa-z]+[\d/]+)           # Resoluciones como entidad
   | (?:Disposici[óo]n[A-Zºo°\sa-z]+[\d/]+)          # Disposicion como entidad
   | (?:Expediente[A-Zºo°\s]+[\d/]+)                 # Expediente como entidad
   | (?:punto\s[\d\.]+)                              # punto x.x.x. como entidad
   | (?:\d{1,2}[\sa-z]+\d{4})                        # fechas
   | (?:[A-Z][a-záéíóú]+\s[A-Z]\.\s[A-Z][a-záéíóú]+) # entidades humanas Fulano M. Mengano
   | (?:MINISTERIO[\sA-Z,]*[A-Z]+)                   # Ministerios como entidad
   | (?:REPUBLICA[\sDE]*[A-Z]+)                      # Republica como entidad
   | (?:SECRETARIA[\sA-Z,]*[A-Z]+)                   # Secretaria como entidad
   | (?:SERVICIO[\sA-Z,]*[A-Z]+)                     # Servicios como entidad
   | (?:DIRECCION[\sA-Z,]*[A-Z]+)                    # Direccion como entidad
   | \w+(?:-\w+)*                                    # palabras con '-' opcional
   | \.\.\.                                          # ...
   | [][.,;"'?():-_`]
   | (?:\d+)                                         # numeros
   | (?:[.\n])                                       # punto y aparte
'''

# %%
# named entities
NE = r'''(?x)
   (?:Ley\sN[ºo°]*\s\d{1,}(?:\.\d+)*)                # Leyes como entidad
   | (?:Nota[\sA-Za-z()ºo°\.]+[\d|/]+)               # Notas como entidad
   | (?:Decreto[A-Zºo°\sa-z]+[\d|/]+)                # Decretos como entidad
   | (?:Resoluci[óo]n[A-Zºo°\sa-z]+[\d/]+)           # Resoluciones como entidad
   | (?:Disposici[óo]n[A-Zºo°\sa-z]+[\d/]+)          # Disposicion como entidad
   | (?:Expediente[A-Zºo°\s]+[\d/]+)                 # Expediente como entidad
   | (?:punto\s[\d\.]+)                              # punto x.x.x. como entidad
   | (?:[A-Z][a-záéíóú]+\s[A-Z]\.\s[A-Z][a-záéíóú]+) # entidades humanas Fulano M. Mengano
   | (?:MINISTERIO[\sA-Z,]*[A-Z]+)                   # Ministerios como entidad
   | (?:REPUBLICA[\sDE]*[A-Z]+)                      # Republica como entidad
   | (?:SECRETARIA[\sA-Z,]*[A-Z]+)                   # Secretaria como entidad
   | (?:SERVICIO[\sA-Z,]*[A-Z]+)                     # Servicios como entidad
   | (?:DIRECCION[\sA-Z,]*[A-Z]+)                    # Direccion como entidad
'''

# %%
# See https://spacy.io/usage/linguistic-features #native-tokenizers
class CustomTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab
    def __call__(self, text):
        words = regexp_tokenize(text, PATTERN)
        # All tokens 'own' a subsequent space character in this tokenizer
        spaces = [True] * len(words)
        return Doc(self.vocab, words=words, spaces=spaces)

# %%
def isEntity(string, pattern):
    return re.match(pattern, string) != None

# %% [markdown]
# ### Preprocessing with spaCy:
# Tokenization with spaCy is prefered here (to nltk) because of it performs well in Spanish with morphological patterns, such as part-of-speech tagging and dependency.

# %%
def preProcessing(dname, PATTERN):
    processed_tokens = []
    nlp = spacy.load("es")
    nlp.tokenizer = CustomTokenizer(nlp.vocab)
    for file in os.listdir(dname):
        if file.endswith(".txt"):
            with open(os.path.join(dname, file), "r") as fd:
                for document in fd.readlines():

                    document = document.strip()
                    nlp.max_length = max(len(document), nlp.max_length)

                    tokens = [ token for token in nlp(document) 
                       if not (token.is_stop or token.is_punct or token.is_digit)
                     ]
            # The complex formatting of these texts makes it hard 
            # to tokenize by sentence so each document will be 
            # one entire law, instead of one sentence.
                    processed_tokens.append(tokens)
    return processed_tokens

# %% [markdown]
# ## Feature Extraction:
# The following features we compose our matrix:
# * Part of speech
# * Dependency Triples, which show the connection between our named entities and the word in the sentence that has the strongest syntactic relationship to that entity, called here ```tok.head.orth_```

# %%
def feature_extraction(processed_tokens):
    database = {}
    for document in preprocessed_tokens:
        has_prev = False
        for idx, tok in enumerate(document):
            if isEntity(tok.text, NE):
                features = {}
                pos = "POS__" + tok.pos_
                if not pos in features:
                    features[pos] = 0
                    features[pos] += 1
                tripla = 'TRIPLA__'+tok.lemma_+'_DEP_' + tok.dep_ + '_HEAD_' + tok.head.orth_
                if not tripla in features:
                    features[tripla] = 0
                    features[tripla] += 1
                database[tok.text] = features
    return database.keys(), database.values()

# %% [markdown]
# ## Code execution

# %%
preprocessed_tokens = preProcessing(PATH, NE)
print(len(preprocessed_tokens))
# Out:
# 1783

# %%
vocabulary, features = feature_extraction(preprocessed_tokens)

# %% [markdown]
# **Vectorization** transforms out words into numerical representations.

# %%
# See https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.DictVectorizer.html
v = DictVectorizer()
vectors = v.fit_transform(features)

# %% [markdown]
# ## Clustering

# %%
num_clusters = 10
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(vectors)
cluster = kmeans.labels_.tolist()

# %%
# Recuento del número de elementos en cada cluster
for i in range(num_clusters):
    print ('Cluster %i has %i elements' % (i, cluster.count(i)))
# Out:
# Cluster 0 has 179 elements
# Cluster 1 has 64 elements
# Cluster 2 has 1 elements
# Cluster 3 has 9 elements
# Cluster 4 has 1 elements
# Cluster 5 has 1 elements
# Cluster 6 has 1 elements
# Cluster 7 has 10 elements
# Cluster 8 has 6 elements
# Cluster 9 has 1 elements

# %%
labels = kmeans.predict(vectors)
labels_words = list(zip(labels, vocabulary))

# %%
clusters = defaultdict(set)
for idc, word in labels_words:
    clusters[idc].add(word)
    
# show clusters
clusters
# Out:
# defaultdict(set,
#             {0: {'DIRECCION DE CONTROL DE BOMBEROS VOLUNTARIOS Y COORDINACION DE ORGANIZACIONES NO GUMERNAMENTALES',
#               'DIRECCION DE CONTROL DE BOMBEROS VOLUNTARIOS Y DE COORDINACION DE ORGANIZACIONES NO GUBERNAMENTALES',
#               'DIRECCION DE PROGRAMACION Y CONTROL PRESUPUESTARIO',
#               'DIRECCION GENERAL DE ADMINISTRACION',
#               'DIRECCION GENERAL DE ASUNTOS JURIDICOS',
#               'DIRECCION NACIONAL DE PROTECCION CIVIL',
#               'DIRECCION NACIONAL DEL REGISTRO OFICIAL',
#               'Decreto 618',
#               'Decreto Nacional Nº 2089/93',
#               'Decreto Nacional Nº 270/97',
#               'Decreto N° 27/2018',
#               'Decreto N° 565/2008',
#               'Decreto N° 618',
#               'Decreto N° 903/2014',
#               'Decreto Nº 1',
#               'Decreto Nº 1474',
#               'Decreto Nº 1697/2004',
#               'Decreto Nº 1759/72',
#               'Decreto Nº 1759/91',
#               'Decreto Nº 180',
#               'Decreto Nº 180/2004',
#               'Decreto Nº 181/04',
#               'Decreto Nº 181/2004',
#               'Decreto Nº 643',
#               'Decretos Nº 1738',
#               'Decretos Nº 1738/92',
#               'Decretos Reglamentarios Nº 380',
#               'Disposición Nº 27',
#               'Disposición SSC Nº 27',
#               'Disposición SSC Nº 27/04',
#               'Disposición de la SUBSECRETARIA DE COMBUSTIBLES Nº 27',
#               'Expediente ENARGAS Nº 8043',
#               'Expediente ENARGAS Nº 9483',
#               'Expediente ENRE Nº 22',
#               'Julio M. De',
#               'Ley No 24.076',
#               'Ley N° 26.178',
#               'Ley N° 26.361',
#               'Ley N° 26.993',
#               'Ley N° 26.994',
#               'Ley N° 27.077',
#               'Ley N° 27.250',
#               'Ley N° 27.265',
#               'Ley N° 27.266',
#               'Ley Nº 11.683',
#               'Ley Nº 13.041',
#               'Ley Nº 13.064',
#               'Ley Nº 17.160',
#               'Ley Nº 19.549',
#               'Ley Nº 19.640',
#               'Ley Nº 22.415',
#               'Ley Nº 22.802',
#               'Ley Nº 24.076',
#               'Ley Nº 24.240',
#               'Ley Nº 24.402',
#               'Ley Nº 24.568',
#               'Ley Nº 24.660',
#               'Ley Nº 24.787',
#               'Ley Nº 24.999',
#               'Ley Nº 25.054',
#               'Ley Nº 25.156',
#               'Ley Nº 25.345',
#               'Ley Nº 25.413',
#               'Ley Nº 25.561',
#               'Ley Nº 25.660',
#               'Ley Nº 25.790',
#               'Ley Nº 25.972',
#               'Ley Nº 26.078',
#               'Ley Nº 26.422',
#               'Ley Nº 26.442',
#               'Ley Nº 3959',
#               'MINISTERIO DE ECONOMIA Y FINANZAS PUBLICAS',
#               'MINISTERIO DE ECONOMIA Y OBRAS Y SERVICIOS PUBLICOS',
#               'MINISTERIO DE ECONOMIA Y PRODUCCION',
#               'MINISTERIO DE JUSTICIA Y DERECHOS HUMANOS',
#               'MINISTERIO DE JUSTICIA, SEGURIDAD Y DERECHOS HUMANOS',
#               'MINISTERIO DE JUSTICIA, SEGURIDAD Y DERECHOS HUMANOS N',
#               'MINISTERIO DE LA PRODUCCION',
#               'MINISTERIO DE PRODUCCION',
#               'María S. Tirabassi',
#               'Nota 519',
#               'Nota DNEH Nro. 143',
#               'Nota DNEH Nro. 260',
#               'Nota DNEH Nº 260',
#               'Nota ENARSA Nº P2262',
#               'Nota ENRG Nº 2975/2004',
#               'Nota ENRG/',
#               'Nota Externa (DGA) Nº 11',
#               'Nota Externa (DGA) Nº 19',
#               'Nota Externa (DGA) Nº 22',
#               'Nota Externa (DGA) Nº 36',
#               'Nota Externa (DGA) Nº 39',
#               'Nota Externa (DGA) Nº 40',
#               'Nota Externa (DGA) Nº 50',
#               'Nota Externa (DGA) Nº 51',
#               'Nota Externa (DGA) Nº 56',
#               'Nota Externa (DGA) Nº 57',
#               'Nota Externa (DGA) Nº 61',
#               'Nota Externa (DGA) Nº 7',
#               'Nota Externa (DGA) Nº 7/09',
#               'Nota Externa (DGA) Nº 72',
#               'Nota Externa (DGA) Nº 75',
#               'Nota Externa (DGA) Nº 81',
#               'Nota Externa (DGA) Nº 89',
#               'Nota Externa (DGA) Nº 95',
#               'Nota Externa N° 40/2009',
#               'Nota Externa N° 63/2009',
#               'Nota Externa Nº 36/2009',
#               'Notas ENRG/',
#               'REPUBLICA ARGENTINA',
#               'REPUBLICA DE BOLIVIA',
#               'Resoluciones ENARGAS Nº 3007',
#               'Resoluciones Generales Nº 100',
#               'Resoluciones Generales Nº 17',
#               'Resoluciones Generales Nº 588',
#               'Resolución ENRE Nº 3/2005',
#               'Resolución General N° 1',
#               'Resolución General N° 2',
#               'Resolución General N° 2040/2006',
#               'Resolución General N° 3397/2012',
#               'Resolución General N° 3880/2016',
#               'Resolución General N° 3984/2017',
#               'Resolución General N° 4035/2017',
#               'Resolución General Nº 1',
#               'Resolución General Nº 100',
#               'Resolución General Nº 1128',
#               'Resolución General Nº 1345',
#               'Resolución General Nº 1351',
#               'Resolución General Nº 1658',
#               'Resolución General Nº 18',
#               'Resolución General Nº 1815',
#               'Resolución General Nº 616',
#               'Resolución General Nº 738',
#               'Resolución MPFIPyS Nº 208/04',
#               'Resolución MPFIPyS Nº 208/2004',
#               'Resolución Ministerial Nº 101',
#               'Resolución N° 1/2018',
#               'Resolución N° 1427/2009',
#               'Resolución N° 15/2009',
#               'Resolución N° 17/2010',
#               'Resolución N° 30/2012',
#               'Resolución N° 80/2009',
#               'Resolución Nº 1067',
#               'Resolución Nº 108',
#               'Resolución Nº 127',
#               'Resolución Nº 154/03',
#               'Resolución Nº 208/04',
#               'Resolución Nº 28/2011',
#               'Resolución Nº 369',
#               'Resolución Nº 422',
#               'Resolución Nº 534',
#               'Resolución Nº 534/06',
#               'Resolución Nº 534/2006',
#               'Resolución Nº 613/94',
#               'Resolución Nº 736',
#               'Resolución Nº 779',
#               'Resolución Nº 834',
#               'Resolución Nº 834/02',
#               'Resolución Nº 91/11',
#               'Resolución SE Nº 659/04',
#               'Resolución SE Nº 659/2004',
#               'Resolución SECRETARIA DE ENERGIA Nº 265/2004',
#               'Resolución SECRETARIA DE ENERGIA Nº 659/2004',
#               'Resolución SENASA Nº 834/2002',
#               'Resolución de este Ministerio Nº 1844',
#               'Resolución de este Ministerio Nº 419/2008',
#               'Resolución del MINISTERIO DE ECONOMIA Y PRODUCCION Nº 127',
#               'SECRETARIA DE AGRICULTURA, GANADERIA Y PESCA',
#               'SECRETARIA DE AGRICULTURA, GANADERIA, PESCA Y ALIMENTACION',
#               'SECRETARIA DE AGRICULTURA, GANADERIA, PESCA Y ALIMENTOS',
#               'SECRETARIA DE AGRICULTURA, PESCA Y ALIMENTACION',
#               'SECRETARIA DE ESTADO DE AGRICULTURA Y GANADERIA',
#               'SECRETARIA DE HACIENDA',
#               'SERVICIO NACIONAL DE SANIDAD Y CALIDAD AGROALIMENTARIA',
#               'SERVICIOS PUBLICOS DOMICILIARIOS',
#               'punto 14',
#               'punto 3.2',
#               'punto 9.4.2.5.',
#               'punto 9.4.2.7.'},
#              1: {'Alberto A. Fernández',
#               'Alberto R. Abad',
#               'Aníbal D. Fernández',
#               'Carlos A. Abalo',
#               'DIRECCION DE CONTROL DE BOMBEROS VOLUNTARIOS Y COORDINACION DE ORGANIZACIONES NO GUBERNAMENTALES',
#               'DIRECCION GENERAL',
#               'DIRECCION GENERAL DE ADUANAS',
#               'DIRECCION NACIONAL DE DEFENSA CIVIL',
#               'DIRECCION NACIONAL DE ECONOMIA DE LOS HIDROCARBUROS',
#               'DIRECCION NACIONAL DE REGISTRO OFICIAL',
#               'Decreto N° 652',
#               'Decreto Nº 101',
#               'Decreto Nº 1183',
#               'Decreto Nº 1183/03',
#               'Decreto Nº 1585',
#               'Decreto Nº 2102',
#               'Decreto Nº 238',
#               'Decreto Nº 3909',
#               'Decreto Nº 583',
#               'Decreto Nº 618',
#               'Decreto Nº 910',
#               'Decreto PEN Nº 181/04',
#               'Decreto Reglamentario de la Ley Nº 11',
#               'Expediente Nº S02',
#               'Ley Nº 26.338',
#               'Mario R. Vidal',
#               'Nota Externa (DGA) Nº 28/06',
#               'Nota Externa (DGA) Nº 52',
#               'Resolución 196/2009',
#               'Resolución 208',
#               'Resolución 474/2009',
#               'Resolución 63/2008',
#               'Resolución General Nº 2755/2010',
#               'Resolución General Nº 4210',
#               'Resolución N° 3227/2005',
#               'Resolución N° 91/2011',
#               'Resolución Nº 262',
#               'Resolución Nº 510',
#               'Resolución a partir del 1',
#               'Resolución de este Ministerio Nº 1919',
#               'Resolución de este Ministerio Nº 2034',
#               'Resolución de este Ministerio Nº 419',
#               'Resolución del MINISTERIO DE ECONOMIA Y PRODUCCION Nº 127/2008',
#               'SERVICIO PENITENCIARIO FEDERAL',
#               'SERVICIOS',
#               'punto 1',
#               'punto 1.2.1',
#               'punto 1.2.2',
#               'punto 1.2.3',
#               'punto 2',
#               'punto 2.',
#               'punto 2.1',
#               'punto 26',
#               'punto 26.',
#               'punto 3.',
#               'punto 3.1.',
#               'punto 3.2.',
#               'punto 3.3',
#               'punto 3.4',
#               'punto 4.',
#               'punto 5',
#               'punto 9.4.2.',
#               'punto 9.4.2.2.',
#               'punto 9.4.2.3.'},
#              2: {'MINISTERIO DE ECONOMIA'},
#              3: {'Decretos Nº 1453',
#               'Eduardo D. Rollano',
#               'Juan H. Estrada',
#               'Ley N° 24.076',
#               'Nota Externa (DGA) Nº 56/09',
#               'Resolución General N° 3',
#               'Resolución General Nº 2000',
#               'Resolución General Nº 2204',
#               'SERVICIO NACIONAL DE SANIDAD ANIMAL'},
#              4: {'Nota Externa (DGA) Nro. 56/09'},
#              5: {'Nota Externa (DGA) Nº 28'},
#              6: {'SECRETARIA DE ENERGIA'},
#              7: {'Decreto 979/2008',
#               'Decreto Nº 855',
#               'Decreto PEN Nº 1959/2006',
#               'Decretos Nº 180',
#               'Nota Externa 59/2009',
#               'Resolución 3208/2005',
#               'Resolución Nº 265',
#               'punto 1.',
#               'punto 4',
#               'punto 7'},
#              8: {'Carlos A. Cheppi',
#               'Fulvio M. Madaro',
#               'MINISTERIO DE PLANIFICACION FEDERAL, INVERSION PUBLICA Y SERVICIOS',
#               'Resolución ENRE Nº 50/2007',
#               'Resolución General 2000',
#               'punto 3.1'},
#              9: {'Expediente Nº 5008/2004'}})
